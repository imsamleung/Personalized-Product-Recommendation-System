# %% [markdown]
# To save time, we use pre-trained model to help us label the sentiment for reviews automatically.

# %% [markdown]
# Import Library

# %%
import nltk
nltk.download('vader_lexicon')
# Out:
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     C:\Users\samle\AppData\Roaming\nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!
# True

# %%
import pandas as pd
import re
from statistics import mean

from nltk.sentiment.vader import SentimentIntensityAnalyzer
from nltk.tokenize import sent_tokenize

# %% [markdown]
# Read Data

# %%
df_reviews = pd.read_json('../../data/final/reviews.json.gz', orient="records", compression="gzip")

# %%
df_reviews.head()
# Out:
#                 user_id  product_id  ratings  \
# 0  A0203183BAH3TR08FZGB  B0043T7FHK        5
# 1  A0261431Y0V4MHWY4B7W  B00AFH2E8E        4
# 2  A034116598G557EYZ9BC  B0013FRNKG        5
# 3  A0404374X0HL5T332XSN  B00MNOPS1C        3
# 4   A0431622H67YR5IPJRN  B0058UUR6E        5
#
#                                          review_text  \
# 0  I got this to run as a dual monitor.  This is ...
# 1  Not as good as I had hoped, music is very low,...
# 2  Appreciate if product\nNeed to buy one more if...
# 3                           You get what you pay for
# 4  Arrived in 2 days. working great. Recommend to...
#
#                                              summary created_at
# 0  This is my second time purchasing this monitor... 2015-06-30
# 1                                  Bluetooth headset 2014-08-03
# 2                                        great value 2012-11-28
# 3                                        Three Stars 2016-02-02
# 4                 working great. Recommend to others 2015-03-11

# %% [markdown]
# Data Preprocessing

# %%
def remove_html_tags(text: str):
    return re.sub(re.compile('<.*?>|&([a-z0-9]+|#[0-9]{1,6}|#x[0-9a-f]{1,6});'), '', text)

def remove_url(text: str):
    return re.sub(r'https?://\S+|www\.\S+', '', text)

def clean_data(text: str):
    text = remove_html_tags(text)
    text = remove_url(text)
    return text

# %%
df_reviews['concatenated_review'] = df_reviews[['review_text', 'summary']].apply(
    lambda x : " ".join(str(y) for y in x if str(y) != 'nan'),
    axis=1
)

df_preprocessing_data = df_reviews[['concatenated_review']].rename(columns = {"concatenated_review" : "review_text"})

# %%
df_preprocessing_data['cleaned_review'] = df_preprocessing_data['review_text'].apply(clean_data)

# %%
df_preprocessing_data.head()
# Out:
#                                          review_text  \
# 0  I got this to run as a dual monitor.  This is ...
# 1  Not as good as I had hoped, music is very low,...
# 2  Appreciate if product\nNeed to buy one more if...
# 3               You get what you pay for Three Stars
# 4  Arrived in 2 days. working great. Recommend to...
#
#                                       cleaned_review
# 0  I got this to run as a dual monitor.  This is ...
# 1  Not as good as I had hoped, music is very low,...
# 2  Appreciate if product\nNeed to buy one more if...
# 3               You get what you pay for Three Stars
# 4  Arrived in 2 days. working great. Recommend to...

# %% [markdown]
# Label Data

# %%
sia = SentimentIntensityAnalyzer()

def get_sentiment_matrix(text: str):
    scores = [
        sia.polarity_scores(sentence)["compound"] for sentence in sent_tokenize(text)
    ]

    compound_score = mean(scores)

    sentiment = 'Neutral'
    sentiment_score = 0
    
    if compound_score >= 0.05:
        sentiment = 'Positive'
        sentiment_score = 1
    elif compound_score <= -0.05:
        sentiment = 'Negative'
        sentiment_score = -1
    
    return pd.Series([compound_score, sentiment, sentiment_score])

# %%
df_preprocessing_data[[
    'compound_score',
    'sentiment',
    'sentiment_score'
]] = df_preprocessing_data["cleaned_review"].apply(lambda x: get_sentiment_matrix(x))

# %%
df_preprocessing_data.head(50)
# Out:
#                                           review_text  \
# 0   I got this to run as a dual monitor.  This is ...
# 1   Not as good as I had hoped, music is very low,...
# 2   Appreciate if product\nNeed to buy one more if...
# 3                You get what you pay for Three Stars
# 4   Arrived in 2 days. working great. Recommend to...
# 5                            VERY GOOD!!!! Five Stars
# 6                               we love it Five Stars
# 7   I was disappointed in the video quality, and s...
# 8   Love this camera, hard to take a bad picture. ...
# 9                                EXCELLENT Five Stars
# 10  This is a fine monitor at a great bargain. Hig...
# 11  It doesn't fully support the Xbox One X graphi...
# 12                                  Good.. Five Stars
# 13  Very good monitor over all. If you're going to...
# 14  These headphones are amazing. I got them but w...
# 15  Bought it just for viewing videos on youtube, ...
# 16  We bought these so that my wife could play mus...
# 17  good replacement desktop , I use it a lot Four...
# 18  Exceptional  machine. I bought the accidental ...
# 19  Very very very slow but does eventually work. ...
# 20  Nice clear sharp image. Took me a while to fig...
# 21  This is a very good monitor I have been using ...
# 22  Looks nice and clean. Decent hardware. Battery...
# 23  Its a nice laptop for the money, better than o...
# 24  junk for a gaming and entertainment laptop. lo...
# 25  Exactly as described and expected,  delivered ...
# 26  Exactly as described on the website and delive...
# 27  outstanding. .perfect... exactly and described...
# 28  I bought a refurb for $110 and love the CB3, a...
# 29  The 12 mega pixel photos look great under opti...
# 30  Excellent monitor that I now use with my 2013 ...
# 31  Debated for a while between the two.  I do mis...
# 32  Fit the home office perfect.  The base/stand c...
# 33  Took me a while to get used to the menu to get...
# 34  There have been over 500 reviews already on th...
# 35  This is a mediocre PC that is useful only to d...
# 36                            A++++++!!!!! Five Stars
# 37                       The curved but ok Five Stars
# 38  Works pretty well, except for on 3 different s...
# 39  Monitor is not adjustable.  At all.  However, ...
# 40  Xmas present for my father-in-law.  He really ...
# 41  These are the only monitors I purchase now, gr...
# 42  Great monitor I purchase these all the time fo...
# 43  This computer is horrible. For not much more y...
# 44  I've used many pair of silicone in-ear headpho...
# 45  Great product, good quality\nWill buy again A+...
# 46  Excellent camera. Wish I knew about the whole ...
# 47  Nice. It is a lil older dvi connector model bu...
# 48  The C195 camera we got from Amazon takes great...
# 49  This camera takes images with great color HOWE...
#
#                                        cleaned_review  compound_score  \
# 0   I got this to run as a dual monitor.  This is ...        0.301557
# 1   Not as good as I had hoped, music is very low,...       -0.052000
# 2   Appreciate if product\nNeed to buy one more if...        0.887400
# 3                You get what you pay for Three Stars       -0.102700
# 4   Arrived in 2 days. working great. Recommend to...        0.394440
# 5                            VERY GOOD!!!! Five Stars        0.000000
# 6                               we love it Five Stars        0.636900
# 7   I was disappointed in the video quality, and s...        0.009220
# 8   Love this camera, hard to take a bad picture. ...        0.302980
# 9                                EXCELLENT Five Stars        0.663300
# 10  This is a fine monitor at a great bargain. Hig...        0.615250
# 11  It doesn't fully support the Xbox One X graphi...       -0.177950
# 12                                  Good.. Five Stars        0.000000
# 13  Very good monitor over all. If you're going to...        0.396600
# 14  These headphones are amazing. I got them but w...        0.228450
# 15  Bought it just for viewing videos on youtube, ...        0.831600
# 16  We bought these so that my wife could play mus...        0.453733
# 17  good replacement desktop , I use it a lot Four...        0.440400
# 18  Exceptional  machine. I bought the accidental ...       -0.091650
# 19  Very very very slow but does eventually work. ...        0.005575
# 20  Nice clear sharp image. Took me a while to fig...        0.238083
# 21  This is a very good monitor I have been using ...        0.625050
# 22  Looks nice and clean. Decent hardware. Battery...        0.214529
# 23  Its a nice laptop for the money, better than o...        0.099015
# 24  junk for a gaming and entertainment laptop. lo...        0.029335
# 25  Exactly as described and expected,  delivered ...        0.868900
# 26  Exactly as described on the website and delive...        0.612400
# 27  outstanding. .perfect... exactly and described...        0.526400
# 28  I bought a refurb for $110 and love the CB3, a...        0.056200
# 29  The 12 mega pixel photos look great under opti...        0.300709
# 30  Excellent monitor that I now use with my 2013 ...        0.571900
# 31  Debated for a while between the two.  I do mis...       -0.038275
# 32  Fit the home office perfect.  The base/stand c...        0.633233
# 33  Took me a while to get used to the menu to get...        0.923100
# 34  There have been over 500 reviews already on th...        0.246250
# 35  This is a mediocre PC that is useful only to d...       -0.015650
# 36                            A++++++!!!!! Five Stars        0.000000
# 37                       The curved but ok Five Stars        0.421500
# 38  Works pretty well, except for on 3 different s...        0.432400
# 39  Monitor is not adjustable.  At all.  However, ...       -0.147182
# 40  Xmas present for my father-in-law.  He really ...        0.174800
# 41  These are the only monitors I purchase now, gr...        0.848100
# 42  Great monitor I purchase these all the time fo...        0.624900
# 43  This computer is horrible. For not much more y...        0.073700
# 44  I've used many pair of silicone in-ear headpho...        0.183425
# 45  Great product, good quality\nWill buy again A+...        0.790600
# 46  Excellent camera. Wish I knew about the whole ...        0.238617
# 47  Nice. It is a lil older dvi connector model bu...        0.271133
# 48  The C195 camera we got from Amazon takes great...        0.239088
# 49  This camera takes images with great color HOWE...       -0.289117
#
#    sentiment  sentiment_score
# 0   Positive                1
# 1   Negative               -1
# 2   Positive                1
# 3   Negative               -1
# 4   Positive                1
# 5    Neutral                0
# 6   Positive                1
# 7    Neutral                0
# 8   Positive                1
# 9   Positive                1
# 10  Positive                1
# 11  Negative               -1
# 12   Neutral                0
# 13  Positive                1
# 14  Positive                1
# 15  Positive                1
# 16  Positive                1
# 17  Positive                1
# 18  Negative               -1
# 19   Neutral                0
# 20  Positive                1
# 21  Positive                1
# 22  Positive                1
# 23  Positive                1
# 24   Neutral                0
# 25  Positive                1
# 26  Positive                1
# 27  Positive                1
# 28  Positive                1
# 29  Positive                1
# 30  Positive                1
# 31   Neutral                0
# 32  Positive                1
# 33  Positive                1
# 34  Positive                1
# 35   Neutral                0
# 36   Neutral                0
# 37  Positive                1
# 38  Positive                1
# 39  Negative               -1
# 40  Positive                1
# 41  Positive                1
# 42  Positive                1
# 43  Positive                1
# 44  Positive                1
# 45  Positive                1
# 46  Positive                1
# 47  Positive                1
# 48  Positive                1
# 49  Negative               -1

# %%
print(df_preprocessing_data["sentiment"].value_counts())
# Out:
# Positive    48619
# Neutral      5620
# Negative     5322
# Name: sentiment, dtype: int64

# %%
df_preprocessing_data.to_json('../data/labelled_reviews.json.gz', compression="gzip", orient="records", indent=2)
